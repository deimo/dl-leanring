# %%
from sndhdr import test_sndr

import torch

# %%
# 1. 四则运算
tensor1 = torch.randint(low=0, high=10, size=(2, 3))
print(tensor1)
# Out:
# tensor([[5, 3, 7],
#         [1, 5, 7]])

# %%
tensor1 + 10
# Out:
# tensor([[15, 13, 17],
#         [11, 15, 17]])

# %%
tensor1
# Out:
# tensor([[5, 3, 7],
#         [1, 5, 7]])

# %%
tensor1.add(10)
# Out:
# tensor([[15, 13, 17],
#         [11, 15, 17]])

# %%
tensor1
# Out:
# tensor([[5, 3, 7],
#         [1, 5, 7]])

# %%
tensor1.add_(10)
# Out:
# tensor([[15, 13, 17],
#         [11, 15, 17]])

# %%
tensor1
# Out:
# tensor([[15, 13, 17],
#         [11, 15, 17]])

# %%
# 幂函数
tensor1 ** 2
# Out:
# tensor([[225, 169, 289],
#         [121, 225, 289]])

# %%
tensor1
# Out:
# tensor([[15, 13, 17],
#         [11, 15, 17]])

# %%
tensor1.pow(2)
# Out:
# tensor([[225, 169, 289],
#         [121, 225, 289]])

# %%
tensor1
# Out:
# tensor([[15, 13, 17],
#         [11, 15, 17]])

# %%
tensor1.pow_(2)
# Out:
# tensor([[225, 169, 289],
#         [121, 225, 289]])

# %%
tensor1
# Out:
# tensor([[225, 169, 289],
#         [121, 225, 289]])

# %%
tensor1.pow(0.5)
# Out:
# tensor([[15., 13., 17.],
#         [11., 15., 17.]])

# %%
tensor1.sqrt()
# Out:
# tensor([[15., 13., 17.],
#         [11., 15., 17.]])

# %%
tensor1
# Out:
# tensor([[225, 169, 289],
#         [121, 225, 289]])

# %%
tensor1.sqrt()
# Out:
# tensor([[15., 13., 17.],
#         [11., 15., 17.]])

# %%
tensor1.sqrt_()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 tensor1.sqrt_()
#
# RuntimeError: result type Float can't be cast to the desired output type Long

# %%
tensor1.float()
# Out:
# tensor([[225., 169., 289.],
#         [121., 225., 289.]])

# %%
tensor1
# Out:
# tensor([[225, 169, 289],
#         [121, 225, 289]])

# %%
tensor1.dtype = torch.float
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 tensor1.dtype = torch.float
#
# AttributeError: attribute 'dtype' of 'torch._C.TensorBase' objects is not writable

# %%
tensor1 = tensor1.float()

# %%
tensor1
# Out:
# tensor([[225., 169., 289.],
#         [121., 225., 289.]])

# %%
tensor1.sqrt_()
# Out:
# tensor([[15., 13., 17.],
#         [11., 15., 17.]])

# %%
tensor1 = torch.tensor([1.0, 2, 3])

# %%
tensor1
# Out:
# tensor([1., 2., 3.])

# %%
tensor1.dtype
# Out:
# torch.float32

# %%
tensor1.exp()
# Out:
# tensor([ 2.7183,  7.3891, 20.0855])

# %%
tensor1
# Out:
# tensor([1., 2., 3.])

# %%
# 计算张量的哈达玛积
tensor1 = torch.tensor([[1, 2], [3, 4]])
tensor2 = torch.tensor([[1, 2], [3, 4]])

# %%
tensor1 + tensor2
# Out:
# tensor([[2, 4],
#         [6, 8]])

# %%
tensor1 * tensor2
# Out:
# tensor([[ 1,  4],
#         [ 9, 16]])

# %%
tensor1.mul(tensor2)
# Out:
# tensor([[ 1,  4],
#         [ 9, 16]])

# %%
tensor1.mul_(tensor2)
# Out:
# tensor([[ 1,  4],
#         [ 9, 16]])

# %%
tensor1
# Out:
# tensor([[ 1,  4],
#         [ 9, 16]])

# %%
# 张量乘法
tensor1 = torch.tensor([[1, 2, 3], [4, 5, 6]])
tensor2 = torch.tensor([[1, 2], [3, 4], [5, 6]])

# %%
tensor1 @ tensor2
# Out:
# tensor([[22, 28],
#         [49, 64]])

# %%
tensor1
# Out:
# tensor([[1, 2, 3],
#         [4, 5, 6]])

# %%
tensor2
# Out:
# tensor([[1, 2],
#         [3, 4],
#         [5, 6]])

# %%
tensor1.mm(tensor2)
# Out:
# tensor([[22, 28],
#         [49, 64]])

# %%
tensor1.matmul(tensor2)
# Out:
# tensor([[22, 28],
#         [49, 64]])

# %%
tensor1 = torch.tensor([[[1, 2, 3], [4, 5, 6]], [[6, 5, 4], [3, 2, 1]]])
tensor2 = torch.tensor([[[1, 2], [3, 4], [5, 6]], [[6, 5], [4, 3], [2, 1]]])

# %%
tensor1.size()
# Out:
# torch.Size([2, 2, 3])

# %%
tensor2.size()
# Out:
# torch.Size([2, 3, 2])

# %%
tensor3 = tensor1.matmul(tensor2)

# %%
tensor3
# Out:
# tensor([[[22, 28],
#          [49, 64]],
#
#         [[64, 49],
#          [28, 22]]])

# %%
tensor3.size()
# Out:
# torch.Size([2, 2, 2])

# %%
# 验证内存的共享和节省内存
X = torch.randint(1, 10, (3, 2, 4))
X
print(id(X))
# Out:
# 4488704896

# %%
# X = X + 10
X += 10
print("after plus: ", id(X))
# Out:
# after plus:  4488704896

# %%
X
# Out:
# tensor([[[15, 19, 19, 11],
#          [13, 15, 12, 13]],
#
#         [[14, 11, 18, 13],
#          [11, 16, 13, 17]],
#
#         [[13, 14, 13, 12],
#          [16, 18, 13, 12]]])

# %%
X = torch.randint(1, 10, (3, 2, 4))
Y = torch.randint(1, 10, (3, 4, 1))
print(X.size())
print(id(X))
print(X)
print(Y)
print(X @ Y)
# X = X @ Y
X[:] = (X @ Y)
print(X)
print(X.size())
print(id(X))
# Out:
# torch.Size([3, 2, 4])
# 4488824608
# tensor([[[8, 2, 3, 9],
#          [6, 8, 6, 8]],
#
#         [[2, 8, 6, 2],
#          [4, 7, 2, 5]],
#
#         [[3, 6, 2, 8],
#          [6, 8, 3, 3]]])
# tensor([[[2],
#          [8],
#          [2],
#          [3]],
#
#         [[1],
#          [4],
#          [6],
#          [4]],
#
#         [[4],
#          [5],
#          [8],
#          [6]]])
# tensor([[[ 65],
#          [112]],
#
#         [[ 78],
#          [ 64]],
#
#         [[106],
#          [106]]])
# tensor([[[ 65,  65,  65,  65],
#          [112, 112, 112, 112]],
#
#         [[ 78,  78,  78,  78],
#          [ 64,  64,  64,  64]],
#
#         [[106, 106, 106, 106],
#          [106, 106, 106, 106]]])
# torch.Size([3, 2, 4])
# 4488824608
